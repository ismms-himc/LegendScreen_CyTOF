# %% [markdown]
# # Legend Screen

# %%
from clustergrammer2 import net

# %% [markdown]
# # All Markers

# %%
net.viz = net.load_json_to_dict('../data/viz_jsons/df_markers.json')
net.widget()
# Out:
# ExampleWidget(network='{"row_nodes": [{"name": "CD112", "ini": 370, "clust": 102, "rank": 38, "rankvar": 85, "…

# %% [markdown]
# # All Markers Z-score

# %%
net.viz = net.load_json_to_dict('../data/viz_jsons/df_markers_z.json')
net.widget()
# Out:
# ExampleWidget(network='{"row_nodes": [{"name": "CD112", "ini": 370, "clust": 111, "rank": 113, "rankvar": 51, …

# %% [markdown]
# # All Cell Types

# %%
net.viz = net.load_json_to_dict('../data/viz_jsons/df_pop_cat.json')
net.widget()
# Out:
# ExampleWidget(network='{"row_nodes": [{"name": "CD298", "ini": 359, "clust": 125, "rank": 351, "rankvar": 265,…

# %% [markdown]
# # All Cell Types Z-score

# %%
net.viz = net.load_json_to_dict('../data/viz_jsons/df_pop_cat_z.json')
net.widget()
# Out:
# ExampleWidget(network='{"row_nodes": [{"name": "CD298", "ini": 359, "clust": 136, "rank": 1, "rankvar": 228, "…
